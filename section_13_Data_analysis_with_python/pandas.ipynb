# %%
# !pip insatall pandas
# Out:
# ERROR: unknown command "insatall" - maybe you meant "install"

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
## creating series -> one dimension dataframes
# from list
data = [1,2,3,4,5]
series = pd.Series(data)
print(series)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
#from dictionary
data = {'a':1,'b':2,'c':2}
series = pd.Series(data)
print(series)
# Out:
# a    1
# b    2
# c    2
# dtype: int64

# %%
#dataFrames -> two dimensional  dataframe
## creating a dataframe from a dist of list
data = {"name":["Rishu","Anjali","Anupriya"],
        "Age":[25,30,45],
        "city":["Kolkata","Mumbai","Bihar"]}
df=pd.DataFrame(data);
print(df)
# Out:
#        name  Age     city
# 0     Rishu   25  Kolkata
# 1    Anjali   30   Mumbai
# 2  Anupriya   45    Bihar

# %%
## creating datframe using list of dictionary
data = [{"name":"krish","age":32,"city":"banglore"},
        {"name":"Rishu","age":21,"city":"kolkata"},
        {"name":"Anjali","age":21,"city":"mumbai"},]
df = pd.DataFrame(data)
print(df)
# Out:
#      name  age      city
# 0   krish   32  banglore
# 1   Rishu   21   kolkata
# 2  Anjali   21    mumbai

# %%
## reading csv file 
df = pd.read_csv("D:\coding file\machine learning\datasets\sales_data_sample.csv",encoding="ISO-8859-1")

# %%
df.head() # it return top 5 row
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
df.head(10) # you can send a number as a parameter and it return that number of row
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
# 5        10168               36      96.66                1  3479.76
# 6        10180               29      86.13                9  2497.77
# 7        10188               48     100.00                1  5512.32
# 8        10201               22      98.57                2  2168.54
# 9        10211               41     100.00               14  4708.44
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# ...
